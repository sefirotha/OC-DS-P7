# %% [markdown]
# # <a id='1'>0. Sommaire</a>

# %% [markdown]
# # <a id='1'>1. Librairies</a>

# %%
import os

import lightgbm_with_simple_features as fe
from importlib import reload

import numpy as np
import pandas as pd
from verstack import NaNImputer
from verstack import PandasOptimizer
import re
import pkg_resources
import types

# %%
def get_imports():
    for name, val in globals().items():
        if isinstance(val, types.ModuleType):
            # Split ensures you get root package, 
            # not just imported function
            name = val.__name__.split(".")[0]

        elif isinstance(val, type):
            name = val.__module__.split(".")[0]
            
        # Some packages are weird and have different
        # imported names vs. system/pip names. Unfortunately,
        # there is no systematic way to get pip names from
        # a package's imported name. You'll have to add
        # exceptions to this list manually!
        poorly_named_packages = {
            "PIL": "Pillow",
            "sklearn": "scikit-learn"
        }
        if name in poorly_named_packages.keys():
            name = poorly_named_packages[name]
            
        yield name
imports = list(set(get_imports()))

# The only way I found to get the version of the root package
# from only the name of the package is to cross-check the names 
# of installed packages vs. imported packages
requirements = []
for m in pkg_resources.working_set:
    if m.project_name in imports and m.project_name!="pip":
        requirements.append((m.project_name, m.version))
for r in requirements:
    print("{}=={}".format(*r))
# Out:
# verstack==3.7.1
# numpy==1.23.5
# pandas==1.5.3

# %% [markdown]
# # 2 . Feature Engineering

# %%
num_rows = None
df = fe.application_train_test(num_rows)
with fe.timer("Process bureau and bureau_balance"):
    bureau = fe.bureau_and_balance(num_rows)
    print("Bureau df shape:", bureau.shape)
    df = df.join(bureau, how='left', on='SK_ID_CURR')
    del bureau
    fe.gc.collect()
with fe.timer("Process previous_applications"):
    prev = fe.previous_applications(num_rows)
    print("Previous applications df shape:", prev.shape)
    df = df.join(prev, how='left', on='SK_ID_CURR')
    del prev
    fe.gc.collect()
with fe.timer("Process POS-CASH balance"):
    pos = fe.pos_cash(num_rows)
    print("Pos-cash balance df shape:", pos.shape)
    df = df.join(pos, how='left', on='SK_ID_CURR')
    del pos
    fe.gc.collect()
with fe.timer("Process installments payments"):
    ins = fe.installments_payments(num_rows)
    print("Installments payments df shape:", ins.shape)
    df = df.join(ins, how='left', on='SK_ID_CURR')
    del ins
    fe.gc.collect()
with fe.timer("Process credit card balance"):
    cc = fe.credit_card_balance(num_rows)
    print("Credit card balance df shape:", cc.shape)
    df = df.join(cc, how='left', on='SK_ID_CURR')
    del cc
# Out:
# Train samples: 307511, test samples: 48744
# Bureau df shape: (305811, 116)
# Process bureau and bureau_balance - done in 31s
# Previous applications df shape: (338857, 249)
# Process previous_applications - done in 35s
# Pos-cash balance df shape: (337252, 18)
# Process POS-CASH balance - done in 16s
# Installments payments df shape: (339587, 26)
# Process installments payments - done in 39s
# Credit card balance df shape: (103558, 141)
# Process credit card balance - done in 19s

# %%
df.replace([np.inf, -np.inf], 0, inplace=True)

# %% [markdown]
# # 3 . Imputation

# %%
df_target = df[["SK_ID_CURR","TARGET"]].copy()

# %%
columns_to_impute = df.keys().to_list()
columns_to_impute.remove("TARGET")

# %%
df_to_impute = df[columns_to_impute].copy()

# %%
# initialize with default parameters
imputer = NaNImputer()
df_imputed = imputer.impute(df_to_impute)
# Out:
#  * Initiating NaNImputer.impute
#      . Dataset dimensions:
#      .. rows:         356251
#      .. columns:      796
#      .. mb in memory: 1849.92
#      .. NaN cols num: 616
#
#    - Drop hopeless NaN cols
#
#    - droped column OWN_CAR_AGE with NaNs and a constant non-NaN value
#
#    - droped column EXT_SOURCE_1 with NaNs and a constant non-NaN value
#
#    - droped column APARTMENTS_AVG with NaNs and a constant non-NaN value
#
#    - droped column BASEMENTAREA_AVG with NaNs and a constant non-NaN value
#
#    - droped column YEARS_BUILD_AVG with NaNs and a constant non-NaN value
#
#    - droped column COMMONAREA_AVG with NaNs and a constant non-NaN value
#
#    - droped column ELEVATORS_AVG with NaNs and a constant non-NaN value
#
#    - droped column ENTRANCES_AVG with NaNs and a constant non-NaN value
#
#    - droped column FLOORSMIN_AVG with NaNs and a constant non-NaN value
#
#    - droped column LANDAREA_AVG with NaNs and a constant non-NaN value
#
#    - droped column LIVINGAPARTMENTS_AVG with NaNs and a constant non-NaN value
#
#    - droped column NONLIVINGAPARTMENTS_AVG with NaNs and a constant non-NaN value
#
#    - droped column NONLIVINGAREA_AVG with NaNs and a constant non-NaN value
#
#    - droped column APARTMENTS_MODE with NaNs and a constant non-NaN value
#
#    - droped column BASEMENTAREA_MODE with NaNs and a constant non-NaN value
#
#    - droped column YEARS_BUILD_MODE with NaNs and a constant non-NaN value
#
#    - droped column COMMONAREA_MODE with NaNs and a constant non-NaN value
#
#    - droped column ELEVATORS_MODE with NaNs and a constant non-NaN value
#
#    - droped column ENTRANCES_MODE with NaNs and a constant non-NaN value
#
#    - droped column FLOORSMIN_MODE with NaNs and a constant non-NaN value
#
#    - droped column LANDAREA_MODE with NaNs and a constant non-NaN value
#
#    - droped column LIVINGAPARTMENTS_MODE with NaNs and a constant non-NaN value
#
#    - droped column NONLIVINGAPARTMENTS_MODE with NaNs and a constant non-NaN value
#
#    - droped column NONLIVINGAREA_MODE with NaNs and a constant non-NaN value
#
#    - droped column APARTMENTS_MEDI with NaNs and a constant non-NaN value
#
#    - droped column BASEMENTAREA_MEDI with NaNs and a constant non-NaN value
#
#    - droped column YEARS_BUILD_MEDI with NaNs and a constant non-NaN value
#
#    - droped column COMMONAREA_MEDI with NaNs and a constant non-NaN value
#
#    - droped column ELEVATORS_MEDI with NaNs and a constant non-NaN value
#
#    - droped column ENTRANCES_MEDI with NaNs and a constant non-NaN value
#
#    - droped column FLOORSMIN_MEDI with NaNs and a constant non-NaN value
#
#    - droped column LANDAREA_MEDI with NaNs and a constant non-NaN value
#
#    - droped column LIVINGAPARTMENTS_MEDI with NaNs and a constant non-NaN value
#
#    - droped column NONLIVINGAPARTMENTS_MEDI with NaNs and a constant non-NaN value
#
#    - droped column NONLIVINGAREA_MEDI with NaNs and a constant non-NaN value
#
#    - droped column BURO_AMT_ANNUITY_MAX with NaNs and a constant non-NaN value
#
#    - droped column BURO_AMT_ANNUITY_MEAN with NaNs and a constant non-NaN value
#
#    - droped column BURO_MONTHS_BALANCE_MIN_MIN with NaNs and a constant non-NaN value
#
#    - droped column BURO_MONTHS_BALANCE_MAX_MAX with NaNs and a constant non-NaN value
#
#    - droped column BURO_MONTHS_BALANCE_SIZE_MEAN with NaNs and a constant non-NaN value
#
#    - droped column BURO_CREDIT_ACTIVE_nan_MEAN with NaNs and a constant non-NaN value
#
#    - droped column BURO_CREDIT_CURRENCY_nan_MEAN with NaNs and a constant non-NaN value
#
#    - droped column BURO_CREDIT_TYPE_nan_MEAN with NaNs and a constant non-NaN value
#
#    - droped column BURO_STATUS_0_MEAN_MEAN with NaNs and a constant non-NaN value
#
#    - droped column BURO_STATUS_1_MEAN_MEAN with NaNs and a constant non-NaN value
#
#    - droped column BURO_STATUS_2_MEAN_MEAN with NaNs and a constant non-NaN value
#
#    - droped column BURO_STATUS_3_MEAN_MEAN with NaNs and a constant non-NaN value
#
#    - droped column BURO_STATUS_4_MEAN_MEAN with NaNs and a constant non-NaN value
#
#    - droped column BURO_STATUS_5_MEAN_MEAN with NaNs and a constant non-NaN value
#
#    - droped column BURO_STATUS_C_MEAN_MEAN with NaNs and a constant non-NaN value
#
#    - droped column BURO_STATUS_X_MEAN_MEAN with NaNs and a constant non-NaN value
#
#    - droped column BURO_STATUS_nan_MEAN_MEAN with NaNs and a constant non-NaN value
#
#    - droped column ACTIVE_DAYS_CREDIT_VAR with NaNs and a constant non-NaN value
#
#    - droped column ACTIVE_AMT_CREDIT_MAX_OVERDUE_MEAN with NaNs and a constant non-NaN value
#
#    - droped column ACTIVE_AMT_ANNUITY_MAX with NaNs and a constant non-NaN value
#
#    - droped column ACTIVE_AMT_ANNUITY_MEAN with NaNs and a constant non-NaN value
#
#    - droped column ACTIVE_MONTHS_BALANCE_MIN_MIN with NaNs and a constant non-NaN value
#
#    - droped column ACTIVE_MONTHS_BALANCE_MAX_MAX with NaNs and a constant non-NaN value
#
#    - droped column ACTIVE_MONTHS_BALANCE_SIZE_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CLOSED_AMT_CREDIT_MAX_OVERDUE_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CLOSED_AMT_ANNUITY_MAX with NaNs and a constant non-NaN value
#
#    - droped column CLOSED_AMT_ANNUITY_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CLOSED_MONTHS_BALANCE_MIN_MIN with NaNs and a constant non-NaN value
#
#    - droped column CLOSED_MONTHS_BALANCE_MAX_MAX with NaNs and a constant non-NaN value
#
#    - droped column CLOSED_MONTHS_BALANCE_SIZE_MEAN with NaNs and a constant non-NaN value
#
#    - droped column PREV_NAME_CONTRACT_TYPE_nan_MEAN with NaNs and a constant non-NaN value
#
#    - droped column PREV_WEEKDAY_APPR_PROCESS_START_nan_MEAN with NaNs and a constant non-NaN value
#
#    - droped column PREV_FLAG_LAST_APPL_PER_CONTRACT_nan_MEAN with NaNs and a constant non-NaN value
#
#    - droped column PREV_NAME_CASH_LOAN_PURPOSE_nan_MEAN with NaNs and a constant non-NaN value
#
#    - droped column PREV_NAME_CONTRACT_STATUS_nan_MEAN with NaNs and a constant non-NaN value
#
#    - droped column PREV_NAME_PAYMENT_TYPE_nan_MEAN with NaNs and a constant non-NaN value
#
#    - droped column PREV_CODE_REJECT_REASON_nan_MEAN with NaNs and a constant non-NaN value
#
#    - droped column PREV_NAME_CLIENT_TYPE_nan_MEAN with NaNs and a constant non-NaN value
#
#    - droped column PREV_NAME_GOODS_CATEGORY_nan_MEAN with NaNs and a constant non-NaN value
#
#    - droped column PREV_NAME_PORTFOLIO_nan_MEAN with NaNs and a constant non-NaN value
#
#    - droped column PREV_NAME_PRODUCT_TYPE_nan_MEAN with NaNs and a constant non-NaN value
#
#    - droped column PREV_CHANNEL_TYPE_nan_MEAN with NaNs and a constant non-NaN value
#
#    - droped column PREV_NAME_SELLER_INDUSTRY_nan_MEAN with NaNs and a constant non-NaN value
#
#    - droped column PREV_NAME_YIELD_GROUP_nan_MEAN with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_AMT_ANNUITY_MIN with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_AMT_ANNUITY_MAX with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_AMT_ANNUITY_MEAN with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_AMT_APPLICATION_MIN with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_AMT_APPLICATION_MAX with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_AMT_APPLICATION_MEAN with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_AMT_CREDIT_MIN with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_AMT_CREDIT_MAX with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_AMT_CREDIT_MEAN with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_APP_CREDIT_PERC_MIN with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_APP_CREDIT_PERC_MAX with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_APP_CREDIT_PERC_MEAN with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_APP_CREDIT_PERC_VAR with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_AMT_DOWN_PAYMENT_MIN with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_AMT_DOWN_PAYMENT_MAX with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_AMT_DOWN_PAYMENT_MEAN with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_AMT_GOODS_PRICE_MIN with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_AMT_GOODS_PRICE_MAX with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_AMT_GOODS_PRICE_MEAN with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_HOUR_APPR_PROCESS_START_MIN with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_HOUR_APPR_PROCESS_START_MAX with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_HOUR_APPR_PROCESS_START_MEAN with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_RATE_DOWN_PAYMENT_MIN with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_RATE_DOWN_PAYMENT_MAX with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_RATE_DOWN_PAYMENT_MEAN with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_DAYS_DECISION_MIN with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_DAYS_DECISION_MAX with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_DAYS_DECISION_MEAN with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_CNT_PAYMENT_MEAN with NaNs and a constant non-NaN value
#
#    - droped column REFUSED_CNT_PAYMENT_SUM with NaNs and a constant non-NaN value
#
#    - droped column POS_NAME_CONTRACT_STATUS_nan_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_MONTHS_BALANCE_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_MONTHS_BALANCE_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_MONTHS_BALANCE_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_MONTHS_BALANCE_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_MONTHS_BALANCE_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_BALANCE_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_BALANCE_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_BALANCE_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_BALANCE_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_BALANCE_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_CREDIT_LIMIT_ACTUAL_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_CREDIT_LIMIT_ACTUAL_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_CREDIT_LIMIT_ACTUAL_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_CREDIT_LIMIT_ACTUAL_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_CREDIT_LIMIT_ACTUAL_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_DRAWINGS_ATM_CURRENT_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_DRAWINGS_ATM_CURRENT_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_DRAWINGS_ATM_CURRENT_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_DRAWINGS_ATM_CURRENT_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_DRAWINGS_ATM_CURRENT_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_DRAWINGS_CURRENT_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_DRAWINGS_CURRENT_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_DRAWINGS_CURRENT_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_DRAWINGS_CURRENT_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_DRAWINGS_CURRENT_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_DRAWINGS_OTHER_CURRENT_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_DRAWINGS_OTHER_CURRENT_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_DRAWINGS_OTHER_CURRENT_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_DRAWINGS_OTHER_CURRENT_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_DRAWINGS_OTHER_CURRENT_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_DRAWINGS_POS_CURRENT_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_DRAWINGS_POS_CURRENT_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_DRAWINGS_POS_CURRENT_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_DRAWINGS_POS_CURRENT_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_DRAWINGS_POS_CURRENT_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_INST_MIN_REGULARITY_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_INST_MIN_REGULARITY_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_INST_MIN_REGULARITY_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_INST_MIN_REGULARITY_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_INST_MIN_REGULARITY_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_PAYMENT_CURRENT_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_PAYMENT_CURRENT_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_PAYMENT_CURRENT_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_PAYMENT_CURRENT_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_PAYMENT_CURRENT_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_PAYMENT_TOTAL_CURRENT_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_PAYMENT_TOTAL_CURRENT_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_PAYMENT_TOTAL_CURRENT_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_PAYMENT_TOTAL_CURRENT_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_PAYMENT_TOTAL_CURRENT_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_RECEIVABLE_PRINCIPAL_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_RECEIVABLE_PRINCIPAL_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_RECEIVABLE_PRINCIPAL_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_RECEIVABLE_PRINCIPAL_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_RECEIVABLE_PRINCIPAL_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_RECIVABLE_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_RECIVABLE_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_RECIVABLE_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_RECIVABLE_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_RECIVABLE_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_TOTAL_RECEIVABLE_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_TOTAL_RECEIVABLE_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_TOTAL_RECEIVABLE_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_TOTAL_RECEIVABLE_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_AMT_TOTAL_RECEIVABLE_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_DRAWINGS_ATM_CURRENT_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_DRAWINGS_ATM_CURRENT_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_DRAWINGS_ATM_CURRENT_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_DRAWINGS_ATM_CURRENT_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_DRAWINGS_ATM_CURRENT_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_DRAWINGS_CURRENT_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_DRAWINGS_CURRENT_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_DRAWINGS_CURRENT_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_DRAWINGS_CURRENT_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_DRAWINGS_CURRENT_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_DRAWINGS_OTHER_CURRENT_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_DRAWINGS_OTHER_CURRENT_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_DRAWINGS_OTHER_CURRENT_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_DRAWINGS_OTHER_CURRENT_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_DRAWINGS_OTHER_CURRENT_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_DRAWINGS_POS_CURRENT_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_DRAWINGS_POS_CURRENT_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_DRAWINGS_POS_CURRENT_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_DRAWINGS_POS_CURRENT_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_DRAWINGS_POS_CURRENT_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_INSTALMENT_MATURE_CUM_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_INSTALMENT_MATURE_CUM_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_INSTALMENT_MATURE_CUM_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_INSTALMENT_MATURE_CUM_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_CNT_INSTALMENT_MATURE_CUM_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_SK_DPD_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_SK_DPD_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_SK_DPD_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_SK_DPD_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_SK_DPD_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_SK_DPD_DEF_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_SK_DPD_DEF_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_SK_DPD_DEF_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_SK_DPD_DEF_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_SK_DPD_DEF_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Active_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Active_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Active_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Active_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Active_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Approved_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Approved_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Approved_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Approved_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Approved_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Completed_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Completed_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Completed_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Completed_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Completed_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Demand_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Demand_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Demand_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Demand_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Demand_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Refused_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Refused_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Refused_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Refused_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Refused_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Sent proposal_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Sent proposal_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Sent proposal_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Sent proposal_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Sent proposal_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Signed_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Signed_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Signed_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Signed_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_Signed_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_nan_MIN with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_nan_MAX with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_nan_MEAN with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_nan_SUM with NaNs and a constant non-NaN value
#
#    - droped column CC_NAME_CONTRACT_STATUS_nan_VAR with NaNs and a constant non-NaN value
#
#    - droped column CC_COUNT with NaNs and a constant non-NaN value
#
#    - Processing whole data for imputation
#      . Processed 10 cols; 355 to go
#      . Processed 20 cols; 345 to go
#
#    - Imputing single core 365 cols
#      . Imputed (regression) - 36       NaN in AMT_ANNUITY
#      . Imputed (regression) - 278      NaN in AMT_GOODS_PRICE
#      . Imputed (regression) - 64648    NaN in DAYS_EMPLOYED
#      . Imputed (multiclass) - 2        NaN in CNT_FAM_MEMBERS
#      . Imputed (regression) - 668      NaN in EXT_SOURCE_2
#      . Imputed (regression) - 69633    NaN in EXT_SOURCE_3
#      . Imputed (regression) - 172862   NaN in YEARS_BEGINEXPLUATATION_AVG
#      . Imputed (regression) - 176340   NaN in FLOORSMAX_AVG
#      . Imputed (regression) - 177901   NaN in LIVINGAREA_AVG
#      . Imputed (regression) - 172862   NaN in YEARS_BEGINEXPLUATATION_MODE
#      . Imputed (regression) - 176340   NaN in FLOORSMAX_MODE
#      . Imputed (regression) - 177901   NaN in LIVINGAREA_MODE
#      . Imputed (regression) - 172862   NaN in YEARS_BEGINEXPLUATATION_MEDI
#      . Imputed (regression) - 176340   NaN in FLOORSMAX_MEDI
#      . Imputed (regression) - 177901   NaN in LIVINGAREA_MEDI
#      . Imputed (regression) - 171054   NaN in TOTALAREA_MODE
#      . Imputed (regression) - 1050     NaN in OBS_30_CNT_SOCIAL_CIRCLE
#      . Imputed (multiclass) - 1050     NaN in DEF_30_CNT_SOCIAL_CIRCLE
#      . Imputed (regression) - 1050     NaN in OBS_60_CNT_SOCIAL_CIRCLE
#      . Imputed (multiclass) - 1050     NaN in DEF_60_CNT_SOCIAL_CIRCLE
#      . Imputed (regression) - 1        NaN in DAYS_LAST_PHONE_CHANGE
#      . Imputed (multiclass) - 47568    NaN in AMT_REQ_CREDIT_BUREAU_HOUR
#      . Imputed (multiclass) - 47568    NaN in AMT_REQ_CREDIT_BUREAU_DAY
#      . Imputed (multiclass) - 47568    NaN in AMT_REQ_CREDIT_BUREAU_WEEK
#      . Imputed (multiclass) - 47568    NaN in AMT_REQ_CREDIT_BUREAU_MON
#      . Imputed (multiclass) - 47568    NaN in AMT_REQ_CREDIT_BUREAU_QRT
#      . Imputed (multiclass) - 47568    NaN in AMT_REQ_CREDIT_BUREAU_YEAR
#      . Imputed (regression) - 64648    NaN in DAYS_EMPLOYED_PERC
#      . Imputed (regression) - 2        NaN in INCOME_PER_PERSON
#      . Imputed (regression) - 36       NaN in ANNUITY_INCOME_PERC
#      . Imputed (regression) - 36       NaN in PAYMENT_RATE
#      . Imputed (regression) - 50444    NaN in BURO_DAYS_CREDIT_MIN
#      . Imputed (regression) - 50444    NaN in BURO_DAYS_CREDIT_MAX
#      . Imputed (regression) - 50444    NaN in BURO_DAYS_CREDIT_MEAN
#      . Imputed (regression) - 91964    NaN in BURO_DAYS_CREDIT_VAR
#      . Imputed (regression) - 53029    NaN in BURO_DAYS_CREDIT_ENDDATE_MIN
#      . Imputed (regression) - 53029    NaN in BURO_DAYS_CREDIT_ENDDATE_MAX
#      . Imputed (regression) - 53029    NaN in BURO_DAYS_CREDIT_ENDDATE_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_DAYS_CREDIT_UPDATE_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_CREDIT_DAY_OVERDUE_MAX
#      . Imputed (regression) - 50444    NaN in BURO_CREDIT_DAY_OVERDUE_MEAN
#      . Imputed (regression) - 143284   NaN in BURO_AMT_CREDIT_MAX_OVERDUE_MEAN
#      . Imputed (regression) - 50446    NaN in BURO_AMT_CREDIT_SUM_MAX
#      . Imputed (regression) - 50446    NaN in BURO_AMT_CREDIT_SUM_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_AMT_CREDIT_SUM_SUM
#      . Imputed (regression) - 58816    NaN in BURO_AMT_CREDIT_SUM_DEBT_MAX
#      . Imputed (regression) - 58816    NaN in BURO_AMT_CREDIT_SUM_DEBT_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_AMT_CREDIT_SUM_DEBT_SUM
#      . Imputed (regression) - 50444    NaN in BURO_AMT_CREDIT_SUM_OVERDUE_MEAN
#      . Imputed (regression) - 75752    NaN in BURO_AMT_CREDIT_SUM_LIMIT_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_AMT_CREDIT_SUM_LIMIT_SUM
#      . Imputed (multiclass) - 50444    NaN in BURO_CNT_CREDIT_PROLONG_SUM
#      . Imputed (regression) - 50444    NaN in BURO_MONTHS_BALANCE_SIZE_SUM
#      . Imputed (regression) - 50444    NaN in BURO_CREDIT_ACTIVE_Active_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_CREDIT_ACTIVE_Bad debt_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_CREDIT_ACTIVE_Closed_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_CREDIT_ACTIVE_Sold_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_CREDIT_CURRENCY_currency 1_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_CREDIT_CURRENCY_currency 2_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_CREDIT_CURRENCY_currency 3_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_CREDIT_CURRENCY_currency 4_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_CREDIT_TYPE_Another type of loan_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_CREDIT_TYPE_Car loan_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_CREDIT_TYPE_Cash loan (non-earmarked)_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_CREDIT_TYPE_Consumer credit_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_CREDIT_TYPE_Credit card_MEAN
#      . Imputed (  binary  ) - 50444    NaN in BURO_CREDIT_TYPE_Interbank credit_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_CREDIT_TYPE_Loan for business development_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_CREDIT_TYPE_Loan for purchase of shares (margin lending)_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_CREDIT_TYPE_Loan for the purchase of equipment_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_CREDIT_TYPE_Loan for working capital replenishment_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_CREDIT_TYPE_Microloan_MEAN
#      . Imputed (  binary  ) - 50444    NaN in BURO_CREDIT_TYPE_Mobile operator loan_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_CREDIT_TYPE_Mortgage_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_CREDIT_TYPE_Real estate loan_MEAN
#      . Imputed (regression) - 50444    NaN in BURO_CREDIT_TYPE_Unknown type of loan_MEAN
#      . Imputed (regression) - 104440   NaN in ACTIVE_DAYS_CREDIT_MIN
#      . Imputed (regression) - 104440   NaN in ACTIVE_DAYS_CREDIT_MAX
#      . Imputed (regression) - 104440   NaN in ACTIVE_DAYS_CREDIT_MEAN
#      . Imputed (regression) - 114909   NaN in ACTIVE_DAYS_CREDIT_ENDDATE_MIN
#      . Imputed (regression) - 114909   NaN in ACTIVE_DAYS_CREDIT_ENDDATE_MAX
#      . Imputed (regression) - 114909   NaN in ACTIVE_DAYS_CREDIT_ENDDATE_MEAN
#      . Imputed (regression) - 104440   NaN in ACTIVE_DAYS_CREDIT_UPDATE_MEAN
#      . Imputed (regression) - 104440   NaN in ACTIVE_CREDIT_DAY_OVERDUE_MAX
#      . Imputed (regression) - 104440   NaN in ACTIVE_CREDIT_DAY_OVERDUE_MEAN
#      . Imputed (regression) - 104443   NaN in ACTIVE_AMT_CREDIT_SUM_MAX
#      . Imputed (regression) - 104443   NaN in ACTIVE_AMT_CREDIT_SUM_MEAN
#      . Imputed (regression) - 104440   NaN in ACTIVE_AMT_CREDIT_SUM_SUM
#      . Imputed (regression) - 116391   NaN in ACTIVE_AMT_CREDIT_SUM_DEBT_MAX
#      . Imputed (regression) - 116391   NaN in ACTIVE_AMT_CREDIT_SUM_DEBT_MEAN
#      . Imputed (regression) - 104440   NaN in ACTIVE_AMT_CREDIT_SUM_DEBT_SUM
#      . Imputed (regression) - 104440   NaN in ACTIVE_AMT_CREDIT_SUM_OVERDUE_MEAN
#      . Imputed (regression) - 138151   NaN in ACTIVE_AMT_CREDIT_SUM_LIMIT_MEAN
#      . Imputed (regression) - 104440   NaN in ACTIVE_AMT_CREDIT_SUM_LIMIT_SUM
#      . Imputed (multiclass) - 104440   NaN in ACTIVE_CNT_CREDIT_PROLONG_SUM
#      . Imputed (regression) - 104440   NaN in ACTIVE_MONTHS_BALANCE_SIZE_SUM
#      . Imputed (regression) - 88330    NaN in CLOSED_DAYS_CREDIT_MIN
#      . Imputed (regression) - 88330    NaN in CLOSED_DAYS_CREDIT_MAX
#      . Imputed (regression) - 88330    NaN in CLOSED_DAYS_CREDIT_MEAN
#      . Imputed (regression) - 150025   NaN in CLOSED_DAYS_CREDIT_VAR
#      . Imputed (regression) - 90083    NaN in CLOSED_DAYS_CREDIT_ENDDATE_MIN
#      . Imputed (regression) - 90083    NaN in CLOSED_DAYS_CREDIT_ENDDATE_MAX
#      . Imputed (regression) - 90083    NaN in CLOSED_DAYS_CREDIT_ENDDATE_MEAN
#      . Imputed (regression) - 88330    NaN in CLOSED_DAYS_CREDIT_UPDATE_MEAN
#      . Imputed (regression) - 88330    NaN in CLOSED_CREDIT_DAY_OVERDUE_MAX
#      . Imputed (regression) - 88330    NaN in CLOSED_CREDIT_DAY_OVERDUE_MEAN
#      . Imputed (regression) - 88330    NaN in CLOSED_AMT_CREDIT_SUM_MAX
#      . Imputed (regression) - 88330    NaN in CLOSED_AMT_CREDIT_SUM_MEAN
#      . Imputed (regression) - 88330    NaN in CLOSED_AMT_CREDIT_SUM_SUM
#      . Imputed (regression) - 101919   NaN in CLOSED_AMT_CREDIT_SUM_DEBT_MAX
#      . Imputed (regression) - 101919   NaN in CLOSED_AMT_CREDIT_SUM_DEBT_MEAN
#      . Imputed (regression) - 88330    NaN in CLOSED_AMT_CREDIT_SUM_DEBT_SUM
#      . Imputed (regression) - 88330    NaN in CLOSED_AMT_CREDIT_SUM_OVERDUE_MEAN
#      . Imputed (regression) - 126314   NaN in CLOSED_AMT_CREDIT_SUM_LIMIT_MEAN
#      . Imputed (regression) - 88330    NaN in CLOSED_AMT_CREDIT_SUM_LIMIT_SUM
#      . Imputed (multiclass) - 88330    NaN in CLOSED_CNT_CREDIT_PROLONG_SUM
#      . Imputed (regression) - 88330    NaN in CLOSED_MONTHS_BALANCE_SIZE_SUM
#      . Imputed (regression) - 17878    NaN in PREV_AMT_ANNUITY_MIN
#      . Imputed (regression) - 17878    NaN in PREV_AMT_ANNUITY_MAX
#      . Imputed (regression) - 17878    NaN in PREV_AMT_ANNUITY_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_AMT_APPLICATION_MIN
#      . Imputed (regression) - 17398    NaN in PREV_AMT_APPLICATION_MAX
#      . Imputed (regression) - 17398    NaN in PREV_AMT_APPLICATION_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_AMT_CREDIT_MIN
#      . Imputed (regression) - 17398    NaN in PREV_AMT_CREDIT_MAX
#      . Imputed (regression) - 17398    NaN in PREV_AMT_CREDIT_MEAN
#      . Imputed (regression) - 17650    NaN in PREV_APP_CREDIT_PERC_MIN
#      . Imputed (regression) - 17650    NaN in PREV_APP_CREDIT_PERC_MAX
#      . Imputed (regression) - 17651    NaN in PREV_APP_CREDIT_PERC_MEAN
#      . Imputed (regression) - 88434    NaN in PREV_APP_CREDIT_PERC_VAR
#      . Imputed (regression) - 37502    NaN in PREV_AMT_DOWN_PAYMENT_MIN
#      . Imputed (regression) - 37502    NaN in PREV_AMT_DOWN_PAYMENT_MAX
#      . Imputed (regression) - 37502    NaN in PREV_AMT_DOWN_PAYMENT_MEAN
#      . Imputed (regression) - 18462    NaN in PREV_AMT_GOODS_PRICE_MIN
#      . Imputed (regression) - 18462    NaN in PREV_AMT_GOODS_PRICE_MAX
#      . Imputed (regression) - 18462    NaN in PREV_AMT_GOODS_PRICE_MEAN
#      . Imputed (multiclass) - 17398    NaN in PREV_HOUR_APPR_PROCESS_START_MIN
#      . Imputed (multiclass) - 17398    NaN in PREV_HOUR_APPR_PROCESS_START_MAX
#      . Imputed (regression) - 17398    NaN in PREV_HOUR_APPR_PROCESS_START_MEAN
#      . Imputed (regression) - 37502    NaN in PREV_RATE_DOWN_PAYMENT_MIN
#      . Imputed (regression) - 37502    NaN in PREV_RATE_DOWN_PAYMENT_MAX
#      . Imputed (regression) - 37502    NaN in PREV_RATE_DOWN_PAYMENT_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_DAYS_DECISION_MIN
#      . Imputed (regression) - 17398    NaN in PREV_DAYS_DECISION_MAX
#      . Imputed (regression) - 17398    NaN in PREV_DAYS_DECISION_MEAN
#      . Imputed (regression) - 17876    NaN in PREV_CNT_PAYMENT_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_CNT_PAYMENT_SUM
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CONTRACT_TYPE_Cash loans_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CONTRACT_TYPE_Consumer loans_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CONTRACT_TYPE_Revolving loans_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CONTRACT_TYPE_XNA_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_WEEKDAY_APPR_PROCESS_START_FRIDAY_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_WEEKDAY_APPR_PROCESS_START_MONDAY_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_WEEKDAY_APPR_PROCESS_START_SATURDAY_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_WEEKDAY_APPR_PROCESS_START_SUNDAY_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_WEEKDAY_APPR_PROCESS_START_THURSDAY_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_WEEKDAY_APPR_PROCESS_START_TUESDAY_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_FLAG_LAST_APPL_PER_CONTRACT_N_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_FLAG_LAST_APPL_PER_CONTRACT_Y_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_Building a house or an annex_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_Business development_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_Buying a garage_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_Buying a holiday home / land_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_Buying a home_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_Buying a new car_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_Buying a used car_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_Car repairs_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_Education_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_Everyday expenses_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_Furniture_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_Gasification / water supply_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_Hobby_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_Journey_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_Medicine_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_Money for a third person_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_Other_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_Payments on other loans_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_Purchase of electronic equipment_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_Refusal to name the goal_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_Repairs_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_Urgent needs_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_Wedding / gift / holiday_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_XAP_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CASH_LOAN_PURPOSE_XNA_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CONTRACT_STATUS_Approved_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CONTRACT_STATUS_Canceled_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CONTRACT_STATUS_Refused_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CONTRACT_STATUS_Unused offer_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_PAYMENT_TYPE_Cash through the bank_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_PAYMENT_TYPE_Cashless from the account of the employer_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_PAYMENT_TYPE_Non-cash from your account_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_PAYMENT_TYPE_XNA_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_CODE_REJECT_REASON_CLIENT_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_CODE_REJECT_REASON_HC_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_CODE_REJECT_REASON_LIMIT_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_CODE_REJECT_REASON_SCO_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_CODE_REJECT_REASON_SCOFR_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_CODE_REJECT_REASON_SYSTEM_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_CODE_REJECT_REASON_VERIF_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_CODE_REJECT_REASON_XAP_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_CODE_REJECT_REASON_XNA_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_TYPE_SUITE_Children_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_TYPE_SUITE_Family_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_TYPE_SUITE_Group of people_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_TYPE_SUITE_Other_A_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_TYPE_SUITE_Other_B_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_TYPE_SUITE_Spouse, partner_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_TYPE_SUITE_Unaccompanied_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_TYPE_SUITE_nan_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CLIENT_TYPE_New_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CLIENT_TYPE_Refreshed_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CLIENT_TYPE_Repeater_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_CLIENT_TYPE_XNA_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Additional Service_MEAN
#      . Imputed (  binary  ) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Animals_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Audio/Video_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Auto Accessories_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Clothing and Accessories_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Computers_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Construction Materials_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Consumer Electronics_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Direct Sales_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Education_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Fitness_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Furniture_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Gardening_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Homewares_MEAN
#      . Imputed (  binary  ) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_House Construction_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Insurance_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Jewelry_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Medical Supplies_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Medicine_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Mobile_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Office Appliances_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Other_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Photo / Cinema Equipment_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Sport and Leisure_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Tourism_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Vehicles_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_Weapon_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_GOODS_CATEGORY_XNA_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_PORTFOLIO_Cards_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_PORTFOLIO_Cars_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_PORTFOLIO_Cash_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_PORTFOLIO_POS_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_PORTFOLIO_XNA_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_PRODUCT_TYPE_XNA_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_PRODUCT_TYPE_walk-in_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_PRODUCT_TYPE_x-sell_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_CHANNEL_TYPE_AP+ (Cash loan)_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_CHANNEL_TYPE_Car dealer_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_CHANNEL_TYPE_Channel of corporate sales_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_CHANNEL_TYPE_Contact center_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_CHANNEL_TYPE_Country-wide_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_CHANNEL_TYPE_Credit and cash offices_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_CHANNEL_TYPE_Regional / Local_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_CHANNEL_TYPE_Stone_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_SELLER_INDUSTRY_Auto technology_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_SELLER_INDUSTRY_Clothing_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_SELLER_INDUSTRY_Connectivity_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_SELLER_INDUSTRY_Construction_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_SELLER_INDUSTRY_Consumer electronics_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_SELLER_INDUSTRY_Furniture_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_SELLER_INDUSTRY_Industry_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_SELLER_INDUSTRY_Jewelry_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_SELLER_INDUSTRY_MLM partners_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_SELLER_INDUSTRY_Tourism_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_SELLER_INDUSTRY_XNA_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_YIELD_GROUP_XNA_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_YIELD_GROUP_high_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_YIELD_GROUP_low_action_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_YIELD_GROUP_low_normal_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_NAME_YIELD_GROUP_middle_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_PRODUCT_COMBINATION_Card Street_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_PRODUCT_COMBINATION_Card X-Sell_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_PRODUCT_COMBINATION_Cash_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_PRODUCT_COMBINATION_Cash Street: high_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_PRODUCT_COMBINATION_Cash Street: low_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_PRODUCT_COMBINATION_Cash Street: middle_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_PRODUCT_COMBINATION_Cash X-Sell: high_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_PRODUCT_COMBINATION_Cash X-Sell: low_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_PRODUCT_COMBINATION_Cash X-Sell: middle_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_PRODUCT_COMBINATION_POS household with interest_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_PRODUCT_COMBINATION_POS household without interest_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_PRODUCT_COMBINATION_POS industry with interest_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_PRODUCT_COMBINATION_POS industry without interest_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_PRODUCT_COMBINATION_POS mobile with interest_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_PRODUCT_COMBINATION_POS mobile without interest_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_PRODUCT_COMBINATION_POS other with interest_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_PRODUCT_COMBINATION_POS others without interest_MEAN
#      . Imputed (regression) - 17398    NaN in PREV_PRODUCT_COMBINATION_nan_MEAN
#      . Imputed (regression) - 18559    NaN in APPROVED_AMT_ANNUITY_MIN
#      . Imputed (regression) - 18559    NaN in APPROVED_AMT_ANNUITY_MAX
#      . Imputed (regression) - 18559    NaN in APPROVED_AMT_ANNUITY_MEAN
#      . Imputed (regression) - 18557    NaN in APPROVED_AMT_APPLICATION_MIN
#      . Imputed (regression) - 18557    NaN in APPROVED_AMT_APPLICATION_MAX
#      . Imputed (regression) - 18557    NaN in APPROVED_AMT_APPLICATION_MEAN
#      . Imputed (regression) - 18557    NaN in APPROVED_AMT_CREDIT_MIN
#      . Imputed (regression) - 18557    NaN in APPROVED_AMT_CREDIT_MAX
#      . Imputed (regression) - 18557    NaN in APPROVED_AMT_CREDIT_MEAN
#      . Imputed (regression) - 18566    NaN in APPROVED_APP_CREDIT_PERC_MIN
#      . Imputed (regression) - 18566    NaN in APPROVED_APP_CREDIT_PERC_MAX
#      . Imputed (regression) - 18566    NaN in APPROVED_APP_CREDIT_PERC_MEAN
#      . Imputed (regression) - 107148   NaN in APPROVED_APP_CREDIT_PERC_VAR
#      . Imputed (regression) - 40203    NaN in APPROVED_AMT_DOWN_PAYMENT_MIN
#      . Imputed (regression) - 40203    NaN in APPROVED_AMT_DOWN_PAYMENT_MAX
#      . Imputed (regression) - 40203    NaN in APPROVED_AMT_DOWN_PAYMENT_MEAN
#      . Imputed (regression) - 19634    NaN in APPROVED_AMT_GOODS_PRICE_MIN
#      . Imputed (regression) - 19634    NaN in APPROVED_AMT_GOODS_PRICE_MAX
#      . Imputed (regression) - 19634    NaN in APPROVED_AMT_GOODS_PRICE_MEAN
#      . Imputed (multiclass) - 18557    NaN in APPROVED_HOUR_APPR_PROCESS_START_MIN
#      . Imputed (multiclass) - 18557    NaN in APPROVED_HOUR_APPR_PROCESS_START_MAX
#      . Imputed (regression) - 18557    NaN in APPROVED_HOUR_APPR_PROCESS_START_MEAN
#      . Imputed (regression) - 40203    NaN in APPROVED_RATE_DOWN_PAYMENT_MIN
#      . Imputed (regression) - 40203    NaN in APPROVED_RATE_DOWN_PAYMENT_MAX
#      . Imputed (regression) - 40203    NaN in APPROVED_RATE_DOWN_PAYMENT_MEAN
#      . Imputed (regression) - 18557    NaN in APPROVED_DAYS_DECISION_MIN
#      . Imputed (regression) - 18557    NaN in APPROVED_DAYS_DECISION_MAX
#      . Imputed (regression) - 18557    NaN in APPROVED_DAYS_DECISION_MEAN
#      . Imputed (regression) - 18557    NaN in APPROVED_CNT_PAYMENT_MEAN
#      . Imputed (regression) - 18557    NaN in APPROVED_CNT_PAYMENT_SUM
#      . Imputed (regression) - 19003    NaN in POS_MONTHS_BALANCE_MAX
#      . Imputed (regression) - 19003    NaN in POS_MONTHS_BALANCE_MEAN
#      . Imputed (regression) - 19003    NaN in POS_MONTHS_BALANCE_SIZE
#      . Imputed (regression) - 19003    NaN in POS_SK_DPD_MAX
#      . Imputed (regression) - 19003    NaN in POS_SK_DPD_MEAN
#      . Imputed (regression) - 19003    NaN in POS_SK_DPD_DEF_MAX
#      . Imputed (regression) - 19003    NaN in POS_SK_DPD_DEF_MEAN
#      . Imputed (regression) - 19003    NaN in POS_NAME_CONTRACT_STATUS_Active_MEAN
#      . Imputed (regression) - 19003    NaN in POS_NAME_CONTRACT_STATUS_Amortized debt_MEAN
#      . Imputed (regression) - 19003    NaN in POS_NAME_CONTRACT_STATUS_Approved_MEAN
#      . Imputed (regression) - 19003    NaN in POS_NAME_CONTRACT_STATUS_Canceled_MEAN
#      . Imputed (regression) - 19003    NaN in POS_NAME_CONTRACT_STATUS_Completed_MEAN
#      . Imputed (regression) - 19003    NaN in POS_NAME_CONTRACT_STATUS_Demand_MEAN
#      . Imputed (regression) - 19003    NaN in POS_NAME_CONTRACT_STATUS_Returned to the store_MEAN
#      . Imputed (regression) - 19003    NaN in POS_NAME_CONTRACT_STATUS_Signed_MEAN
#      . Imputed (regression) - 19003    NaN in POS_NAME_CONTRACT_STATUS_XNA_MEAN
#      . Imputed (regression) - 19003    NaN in POS_COUNT
#      . Imputed (regression) - 16668    NaN in INSTAL_NUM_INSTALMENT_VERSION_NUNIQUE
#      . Imputed (regression) - 16668    NaN in INSTAL_DPD_MAX
#      . Imputed (regression) - 16668    NaN in INSTAL_DPD_MEAN
#      . Imputed (regression) - 16668    NaN in INSTAL_DPD_SUM
#      . Imputed (regression) - 16668    NaN in INSTAL_DBD_MAX
#      . Imputed (regression) - 16668    NaN in INSTAL_DBD_MEAN
#      . Imputed (regression) - 16668    NaN in INSTAL_DBD_SUM
#      . Imputed (regression) - 16677    NaN in INSTAL_PAYMENT_PERC_MAX
#      . Imputed (regression) - 16696    NaN in INSTAL_PAYMENT_PERC_MEAN
#      . Imputed (regression) - 16687    NaN in INSTAL_PAYMENT_PERC_SUM
#      . Imputed (regression) - 17664    NaN in INSTAL_PAYMENT_PERC_VAR
#      . Imputed (regression) - 16677    NaN in INSTAL_PAYMENT_DIFF_MAX
#      . Imputed (regression) - 16677    NaN in INSTAL_PAYMENT_DIFF_MEAN
#      . Imputed (regression) - 16668    NaN in INSTAL_PAYMENT_DIFF_SUM
#      . Imputed (regression) - 17645    NaN in INSTAL_PAYMENT_DIFF_VAR
#      . Imputed (regression) - 16668    NaN in INSTAL_AMT_INSTALMENT_MAX
#      . Imputed (regression) - 16668    NaN in INSTAL_AMT_INSTALMENT_MEAN
#      . Imputed (regression) - 16668    NaN in INSTAL_AMT_INSTALMENT_SUM
#      . Imputed (regression) - 16677    NaN in INSTAL_AMT_PAYMENT_MIN
#      . Imputed (regression) - 16677    NaN in INSTAL_AMT_PAYMENT_MAX
#      . Imputed (regression) - 16677    NaN in INSTAL_AMT_PAYMENT_MEAN
#      . Imputed (regression) - 16668    NaN in INSTAL_AMT_PAYMENT_SUM
#      . Imputed (regression) - 16677    NaN in INSTAL_DAYS_ENTRY_PAYMENT_MAX
#      . Imputed (regression) - 16677    NaN in INSTAL_DAYS_ENTRY_PAYMENT_MEAN
#      . Imputed (regression) - 16668    NaN in INSTAL_DAYS_ENTRY_PAYMENT_SUM
#      . Imputed (regression) - 16668    NaN in INSTAL_COUNT
#
#    - Missing values after imputation: 0
#
# Time elapsed for function impute execution: 1 hour(s) 9 min 19 sec

# %%
df_imputed.isna().sum()
# Out:
# SK_ID_CURR                        0
# CODE_GENDER                       0
# FLAG_OWN_CAR                      0
# FLAG_OWN_REALTY                   0
# CNT_CHILDREN                      0
#                                  ..
# INSTAL_AMT_PAYMENT_SUM            0
# INSTAL_DAYS_ENTRY_PAYMENT_MAX     0
# INSTAL_DAYS_ENTRY_PAYMENT_MEAN    0
# INSTAL_DAYS_ENTRY_PAYMENT_SUM     0
# INSTAL_COUNT                      0
# Length: 545, dtype: int64

# %%
df_final = pd.merge(df_target, df_imputed, left_on = "SK_ID_CURR", right_on = "SK_ID_CURR", how = "left")

# %% [markdown]
# # 4 . Optimization mémoire

# %%
opt = PandasOptimizer()

# %%
df_final_opt = opt.optimize_memory_usage(df_final)
# Out:
#    - Original data size: 1170.43 MB
#
#    - Optimized data size: 429.44 MB
#
#    - Optimized data percentage of origianl data: 36.69%

# %%
# Change columns names ([LightGBM] Do not support special JSON characters in feature name.)
new_names = {col: re.sub(r'[^A-Za-z0-9_]+', '', col) for col in df_final_opt.columns}
new_n_list = list(new_names.values())
# [LightGBM] Feature appears more than one time.
new_names = {col: f'{new_col}_{i}' if new_col in new_n_list[:i] else new_col for i, (col, new_col) in enumerate(new_names.items())}
df_final_opt = df_final_opt.rename(columns=new_names)

# %%
df_final_opt.to_pickle("..\Data\Processed_data\df_final_prot5.pkl", protocol=5)

# %%
df_final_opt.to_pickle("..\Data\Processed_data\df_final_prot0.pkl", protocol=-1)

# %%
train_df = df[df['TARGET'].notnull()]
test_df = df[df['TARGET'].isnull()]

# %%
train_df.to_pickle(r"..\Data\Processed_data\train_df.pkl", protocol=-1)
test_df.to_pickle(r"..\Data\Processed_data\test_df.pkl", protocol=-1)
